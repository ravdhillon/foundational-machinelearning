# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import os

from pylab import rcParams
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4

# %%
excerise_root_dir = os.path.join(os.getcwd(), 'Python_DS_Excerise', 'ExcerciseFiles')
data_folder = os.path.join(excerise_root_dir, 'Data')
data_folder
# Out:
# '/Users/ravisher/Development/FatehLabs/machine-learning-projects/Python_DS_Excerise/ExcerciseFiles/Data'

# %%
import seaborn as sb
sb.set_style('whitegrid')
from collections import Counter

# %%
enrollment_data_path = os.path.join(data_folder, 'enrollment_forecast.csv')
enroll_data = pd.read_csv(enrollment_data_path)
enroll_data.head()
# Out:
#    year  roll  unem  hgrad   inc
# 0     1  5501   8.1   9552  1923
# 1     2  5945   7.0   9680  1961
# 2     3  6629   7.3   9731  1979
# 3     4  7556   7.5  11666  2030
# 4     5  8716   7.0  14675  2112

# %%
enroll_data.columns
# Out:
# Index(['year', 'roll', 'unem', 'hgrad', 'inc'], dtype='object')

# %%
sb.pairplot(enroll_data)

# %%
enroll_data.corr()
# Out:
#            year      roll      unem     hgrad       inc
# year   1.000000  0.900934  0.378305  0.670300  0.944287
# roll   0.900934  1.000000  0.391344  0.890294  0.949876
# unem   0.378305  0.391344  1.000000  0.177376  0.282310
# hgrad  0.670300  0.890294  0.177376  1.000000  0.820089
# inc    0.944287  0.949876  0.282310  0.820089  1.000000

# %%
# we are checking unem and hgrad to understand what relationship they show.
enroll = enroll_data[['unem', 'hgrad']].values
enroll_target = enroll[tuple('roll')].values
enroll_data_names = ['unem', 'hgrad']
X, y = scale(enroll_data), enroll_target
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-218b30a60a03> in <module>
#       1 # we are checking unem and hgrad to understand what relationship they show.
#       2 enroll = enroll_data[['unem', 'hgrad']].values
# ----> 3 enroll_target = enroll[tuple('roll')].values
#       4 enroll_data_names = ['unem', 'hgrad']
#       5 X, y = scale(enroll_data), enroll_target
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
